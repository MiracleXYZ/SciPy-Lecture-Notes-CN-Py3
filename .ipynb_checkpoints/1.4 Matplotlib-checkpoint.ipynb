# %% [markdown]
# # 1.4 Matplotlib：绘图

# %% [markdown]
# ## 1.4.1 简介

# %% [markdown]
# ### 1.4.1.1 IPython和pylab模式

# %% [markdown]
# ### 1.4.1.2 pylab
#
# 提供matplotlib面向对象的绘图库的程序接口，模型与MATLAB相近。

# %% [markdown]
# ## 1.4.2 简单绘图
#
# 从默认设置开始，我们将不断丰富图片，让它看起来更漂亮。

# %%
from matplotlib import rc
rc('font', **{'family': 'serif', 'serif': ['Times']})
rc('text', usetex=True)

# %matplotlib inline

# %%
import numpy as np

X = np.linspace(-np.pi, np.pi, 256, endpoint=True)
C, S = np.cos(X), np.sin(X)

# %% [markdown]
# ### 1.4.2.1 用默认设置绘图
#
# 自定义属性：
#
# - 图片大小和dpi
# - 线长度
# - 颜色和样式
# - 坐标轴
# - 坐标轴和网格属性
# - 文本和字体属性

# %%
import pylab as pl
import numpy as np

# %%
pl.plot(X, C)
pl.plot(X, S)

pl.show()

# %% [markdown]
# ### 1.4.2.2 默认值示例

# %%
pl.figure(figsize=(8, 6), dpi=80)

pl.subplot(1, 1, 1)

pl.plot(X, C, color='blue', linewidth=1.0, linestyle='-')

pl.plot(X, S, color='green', linewidth=1.0, linestyle='-')

pl.xlim(-4.0, 4.0)
pl.xticks(np.linspace(-4, 4, 9, endpoint=True))

pl.ylim(-1.0, 1.0)
pl.yticks(np.linspace(-1, 1, 5, endpoint=True))

pl.savefig('save/pylab/exercise_2.png', dpi=72)
pl.show()

# %% [markdown]
# ### 1.4.2.3 改变颜色和线宽度
#
# - 控制线属性
# - 线API

# %%
pl.figure(figsize=(10, 6), dpi=80)
pl.plot(X, C, color='blue', linewidth=2.5, linestyle='-')
pl.plot(X, S, color='red', linewidth=2.5, linestyle='-')

# %% [markdown]
# ### 1.4.2.4 设置极值

# %%
pl.figure(figsize=(10, 6), dpi=80)
pl.plot(X, C, color='blue', linewidth=2.5, linestyle='-')
pl.plot(X, S, color='red', linewidth=2.5, linestyle='-')

pl.xlim(X.min() * 1.1, X.max() * 1.1)
pl.ylim(C.min() * 1.1, C.max() * 1.1)
# Out:
# (-1.1000000000000001, 1.0999165211263138)

# %% [markdown]
# ### 1.4.2.5 设置坐标轴刻度值

# %%
pl.figure(figsize=(10, 6), dpi=80)
pl.plot(X, C, color='blue', linewidth=2.5, linestyle='-')
pl.plot(X, S, color='red', linewidth=2.5, linestyle='-')
pl.xlim(X.min() * 1.1, X.max() * 1.1)
pl.ylim(C.min() * 1.1, C.max() * 1.1)

pl.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi])
pl.yticks([-1, 0, +1])
# Out:
# ([<matplotlib.axis.YTick at 0x1fb99453a58>,
#   <matplotlib.axis.YTick at 0x1fb995021d0>,
#   <matplotlib.axis.YTick at 0x1fb9951cc18>],
#  <a list of 3 Text yticklabel objects>)

# %% [markdown]
# ### 1.4.2.6 设置刻度标签
#
# 在第二个参数中列出对应的标签
#
# 使用$\LaTeX$以便更好的渲染标签

# %%
pl.figure(figsize=(10, 6), dpi=80)
pl.plot(X, C, color='blue', linewidth=2.5, linestyle='-')
pl.plot(X, S, color='red', linewidth=2.5, linestyle='-')
pl.xlim(X.min() * 1.1, X.max() * 1.1)
pl.ylim(C.min() * 1.1, C.max() * 1.1)

pl.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
          [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])
pl.yticks([-1, 0, +1],
          [r'$-1$', r'$0$', r'$+1$'])
# Out:
# ([<matplotlib.axis.YTick at 0x1fb995de908>,
#   <matplotlib.axis.YTick at 0x1fb995dea20>,
#   <matplotlib.axis.YTick at 0x1fb995de160>],
#  <a list of 3 Text yticklabel objects>)

# %% [markdown]
# ### 1.4.2.7 移动脊柱

# %%
pl.figure(figsize=(10, 6), dpi=80)
pl.plot(X, C, color='blue', linewidth=2.5, linestyle='-')
pl.plot(X, S, color='red', linewidth=2.5, linestyle='-')
pl.xlim(X.min() * 1.1, X.max() * 1.1)
pl.ylim(C.min() * 1.1, C.max() * 1.1)
pl.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
          [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])
pl.yticks([-1, 0, +1],
          [r'$-1$', r'$0$', r'$+1$'])

ax = pl.gca() # get current axis
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))

# %% [markdown]
# ### 1.4.2.8 添加图例

# %%
pl.figure(figsize=(10, 6), dpi=80)
pl.plot(X, C, color='blue', linewidth=2.5, linestyle='-', label='cosine') # label
pl.plot(X, S, color='red', linewidth=2.5, linestyle='-', label='sine') # label
pl.xlim(X.min() * 1.1, X.max() * 1.1)
pl.ylim(C.min() * 1.1, C.max() * 1.1)
pl.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
          [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])
pl.yticks([-1, 0, +1],
          [r'$-1$', r'$0$', r'$+1$'])
ax = pl.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))

pl.legend(loc='upper left')

# %% [markdown]
# ### 1.4.2.9 标注一些点
#
# 用annotate命令标注一些有趣的点
#
# - 画出垂直的散点标记线
# - annotate显示带有箭头的文字

# %%
pl.figure(figsize=(10, 6), dpi=120)
pl.plot(X, C, color='blue', linewidth=2.5, linestyle='-', label='cosine') # label
pl.plot(X, S, color='red', linewidth=2.5, linestyle='-', label='sine') # label
pl.xlim(X.min() * 1.1, X.max() * 1.1)
pl.ylim(C.min() * 1.1, C.max() * 1.1)
pl.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
          [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])
pl.yticks([-1, 0, +1],
          [r'$-1$', r'$0$', r'$+1$'])
ax = pl.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))
pl.legend(loc='upper left')


t = 2 * np.pi / 3
pl.plot([t, t], [0, np.cos(t)], color='blue', linewidth=2.5, linestyle='--')
pl.scatter([t,], [np.cos(t),], 50, color='blue')

pl.annotate(r'$\sin(\frac{2\pi}{3})=\frac{\sqrt{3}}{2}$',
            xy=(t, np.sin(t)), xycoords='data',
            xytext=(+10, +30), textcoords='offset points', fontsize=16,
            arrowprops=dict(arrowstyle='->', connectionstyle='arc3,rad=.2'))

pl.plot([t, t], [0, np.sin(t)], color='red', linewidth=2.5, linestyle='--')
pl.scatter([t,], [np.sin(t),], 50, color='red')

pl.annotate(r'$\cos(\frac{2\pi}{3})=-\frac{1}{2}$',
            xy=(t, np.cos(t)), xycoords='data',
            xytext=(-90, -50), textcoords='offset points', fontsize=16,
            arrowprops=dict(arrowstyle='->', connectionstyle='arc3,rad=.2'))

pl.show()

# %% [markdown]
# ### 1.4.2.10 细节是魔鬼

# %%
pl.figure(figsize=(10, 6), dpi=120)
pl.plot(X, C, color='blue', linewidth=2.5, linestyle='-', label='cosine') # label
pl.plot(X, S, color='red', linewidth=2.5, linestyle='-', label='sine') # label
pl.xlim(X.min() * 1.1, X.max() * 1.1)
pl.ylim(C.min() * 1.1, C.max() * 1.1)
pl.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
          [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])
pl.yticks([-1, 0, +1],
          [r'$-1$', r'$0$', r'$+1$'])
ax = pl.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))
pl.legend(loc='upper left')
t = 2 * np.pi / 3
pl.plot([t, t], [0, np.cos(t)], color='blue', linewidth=2.5, linestyle='--')
pl.scatter([t,], [np.cos(t),], 50, color='blue')
pl.annotate(r'$\sin(\frac{2\pi}{3})=\frac{\sqrt{3}}{2}$',
            xy=(t, np.sin(t)), xycoords='data',
            xytext=(+10, +30), textcoords='offset points', fontsize=16,
            arrowprops=dict(arrowstyle='->', connectionstyle='arc3,rad=.2'))
pl.plot([t, t], [0, np.sin(t)], color='red', linewidth=2.5, linestyle='--')
pl.scatter([t,], [np.sin(t),], 50, color='red')
pl.annotate(r'$\cos(\frac{2\pi}{3})=-\frac{1}{2}$',
            xy=(t, np.cos(t)), xycoords='data',
            xytext=(-90, -50), textcoords='offset points', fontsize=16,
            arrowprops=dict(arrowstyle='->', connectionstyle='arc3,rad=.2'))

for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontsize(16)
    label.set_bbox(dict(facecolor='white', edgecolor='None',  alpha=0.65))

pl.show()

# %% [markdown]
# 让刻度更大一些，或者处理为半透明的白色背景。

# %% [markdown]
# ## 1.4.3 图形、子图、轴和刻度

# %% [markdown]
# 使用图形、子图和轴我们可以控制显示

# %% [markdown]
# ### 1.4.3.1 图形
#
# 图形标号从1开始（明显是MATLAB风格）
#
# - num
# - figsize
# - dpi
# - facecolor
# - edgecolor
# - frameon

# %% [raw]
# pl.close(1)

# %% [markdown]
# ### 1.4.3.2 子图
#
# 将图片放置在标准方格中
#
# 指定行列数和图片数
#
# `gridspec`更加高级

# %% [markdown]
# ### 1.4.3.3 轴

# %% [markdown]
# 与子图相似，但是允许图形放在图片的**任意位置**

# %% [markdown]
# ### 1.4.3.4 刻度

# %% [markdown]
# #### 1.4.3.4.1 刻度位置

# %% [raw]
# ax = pl.gca()
# ax.xaxis.set_major_locator(eval(locator))

# %% [markdown]
# `matplotlib`为日期提供了特殊的位置`matplotlib.dates`

# %% [markdown]
# ## 1.4.4 其他类型的图形：例子与练习

# %% [markdown]
# ### 1.4.4.1 常规图形

# %%
import numpy as np
import matplotlib.pyplot as plt

n = 256
X = np.linspace(-np.pi, np.pi, n, endpoint=True)
Y = np.sin(2 * X)

plt.axes([0.025, 0.025, 0.95, 0.95])

plt.plot(X, Y + 1, color='blue', alpha=1.00)
plt.fill_between(X, 1, Y + 1, color='blue', alpha=.25)

plt.plot(X, Y - 1, color='blue', alpha=1.00)
plt.fill_between(X, -1, Y - 1, (Y - 1) > -1, color='blue', alpha=.25)
plt.fill_between(X, -1, Y - 1, (Y - 1) < -1, color='red',  alpha=.25)

plt.xlim(-np.pi, np.pi)
plt.xticks(())
plt.ylim(-2.5, 2.5)
plt.yticks(())

plt.show()

# %% [markdown]
# ### 1.4.4.2 散点图

# %%
n = 1024
X = np.random.normal(0, 1, n)
Y = np.random.normal(0, 1, n)
T = np.arctan2(Y, X)

plt.axes([0.025, 0.025, 0.95, 0.95])
plt.scatter(X, Y, s=75, c=T, alpha=.5)

plt.xlim(-1.5, 1.5)
plt.xticks(())
plt.ylim(-1.5, 1.5)
plt.yticks(())

plt.show()

# %% [markdown]
# ### 1.4.4.3 柱状图

# %% [markdown]
# 提示：小心文本**对齐**

# %%
n = 12
X = np.arange(n)
Y1 = (1 - X / float(n)) * np.random.uniform(0.5, 1.0, n)
Y2 = (1 - X / float(n)) * np.random.uniform(0.5, 1.0, n)

plt.axes([0.025, 0.025, 0.95, 0.95])
plt.bar(X, +Y1, facecolor='#9999ff', edgecolor='white')
plt.bar(X, -Y2, facecolor='#ff9999', edgecolor='white')

for x, y in zip(X, Y1):
    plt.text(x, y + 0.05, '%.2f' % y, ha='center', va= 'bottom')

for x, y in zip(X, Y2):
    plt.text(x, -y - 0.05, '%.2f' % y, ha='center', va= 'top')

plt.xlim(-.5, n)
plt.xticks(())
plt.ylim(-1.25, 1.25)
plt.yticks(())

plt.show()

# %% [markdown]
# ### 1.4.4.4 轮廓图

# %%
def f(x,y):
    return (1 - x / 2 + x**5 + y**3) * np.exp(-x**2 -y**2)

n = 256
x = np.linspace(-3, 3, n)
y = np.linspace(-3, 3, n)
X,Y = np.meshgrid(x, y)

plt.axes([0.025, 0.025, 0.95, 0.95])

plt.contourf(X, Y, f(X, Y), 8, alpha=.75, cmap=plt.cm.hot)
C = plt.contour(X, Y, f(X, Y), 8, colors='black', linewidth=.5)
plt.clabel(C, inline=1, fontsize=10)

plt.xticks(())
plt.yticks(())
plt.show()

# %% [markdown]
# ### 1.4.4.5 imshow

# %%
def f(x, y):
    return (1 - x / 2 + x ** 5 + y ** 3 ) * np.exp(-x ** 2 - y ** 2)

n = 10
x = np.linspace(-3, 3, 3.5 * n)
y = np.linspace(-3, 3, 3.0 * n)
X, Y = np.meshgrid(x, y)
Z = f(X, Y)

plt.axes([0.025, 0.025, 0.95, 0.95])
plt.imshow(Z, interpolation='nearest', cmap='bone', origin='lower')
plt.colorbar(shrink=.92)

plt.xticks(())
plt.yticks(())
plt.show()
# Out:
# C:\Users\xieyu\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:5: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
# C:\Users\xieyu\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:6: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.

# %% [markdown]
# ### 1.4.4.6 饼图

# %%
n = 20
Z = np.ones(n)
Z[-1] *= 2

plt.axes([0.025, 0.025, 0.95, 0.95])

plt.pie(Z, explode=Z*.05, colors = ['%f' % (i/float(n)) for i in range(n)])
plt.axis('equal')
plt.xticks(())
plt.yticks()

plt.show()

# %% [markdown]
# ### 1.4.4.7 梯度图

# %% [markdown]
# 需要绘制**两次**箭头

# %%
n = 8
X, Y = np.mgrid[0:n, 0:n]
T = np.arctan2(Y - n / 2., X - n/2.)
R = 10 + np.sqrt((Y - n / 2.0) ** 2 + (X - n / 2.0) ** 2)
U, V = R * np.cos(T), R * np.sin(T)

plt.axes([0.025, 0.025, 0.95, 0.95])
plt.quiver(X, Y, U, V, R, alpha=.5)
plt.quiver(X, Y, U, V, edgecolor='k', facecolor='None', linewidth=.5)

plt.xlim(-1, n)
plt.xticks(())
plt.ylim(-1, n)
plt.yticks(())

plt.show()

# %% [markdown]
# ### 1.4.4.8 网格

# %%
ax = plt.axes([0.025, 0.025, 0.95, 0.95])

ax.set_xlim(0,4)
ax.set_ylim(0,3)
ax.xaxis.set_major_locator(plt.MultipleLocator(1.0))
ax.xaxis.set_minor_locator(plt.MultipleLocator(0.1))
ax.yaxis.set_major_locator(plt.MultipleLocator(1.0))
ax.yaxis.set_minor_locator(plt.MultipleLocator(0.1))
ax.grid(which='major', axis='x', linewidth=0.75, linestyle='-', color='0.75')
ax.grid(which='minor', axis='x', linewidth=0.25, linestyle='-', color='0.75')
ax.grid(which='major', axis='y', linewidth=0.75, linestyle='-', color='0.75')
ax.grid(which='minor', axis='y', linewidth=0.25, linestyle='-', color='0.75')
ax.set_xticklabels([])
ax.set_yticklabels([])

plt.show()

# %% [markdown]
# ### 1.4.4.9 多图

# %%
fig = plt.figure()
fig.subplots_adjust(bottom=0.025, left=0.025, top = 0.975, right=0.975)

plt.subplot(2, 1, 1)
plt.xticks(()), plt.yticks(())

plt.subplot(2, 3, 4)
plt.xticks(())
plt.yticks(())

plt.subplot(2, 3, 5)
plt.xticks(())
plt.yticks(())

plt.subplot(2, 3, 6)
plt.xticks(())
plt.yticks(())

plt.show()

# %% [markdown]
# ### 1.4.4.10 极坐标系

# %%
ax = plt.axes([0.025, 0.025, 0.95, 0.95], polar=True)

N = 20
theta = np.arange(0.0, 2 * np.pi, 2 * np.pi / N)
radii = 10 * np.random.rand(N)
width = np.pi / 4 * np.random.rand(N)
bars = plt.bar(theta, radii, width=width, bottom=0.0)

for r,bar in zip(radii, bars):
    bar.set_facecolor(plt.cm.jet(r/10.))
    bar.set_alpha(0.5)

ax.set_xticklabels([])
ax.set_yticklabels([])
plt.show()

# %% [markdown]
# ### 1.4.4.11 3D绘图

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = Axes3D(fig)
X = np.arange(-4, 4, 0.25)
Y = np.arange(-4, 4, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X ** 2 + Y ** 2)
Z = np.sin(R)

ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=plt.cm.hot)
ax.contourf(X, Y, Z, zdir='z', offset=-2, cmap=plt.cm.hot)
ax.set_zlim(-2, 2)

plt.show()

# %% [markdown]
# ### 1.4.4.12 文本

# %%
eqs = []
eqs.append((r"$W^{3\beta}_{\delta_1 \rho_1 \sigma_2} = U^{3\beta}_{\delta_1 \rho_1} + \frac{1}{8 \pi 2} \int^{\alpha_2}_{\alpha_2} d \alpha^\prime_2 \left[\frac{ U^{2\beta}_{\delta_1 \rho_1} - \alpha^\prime_2U^{1\beta}_{\rho_1 \sigma_2} }{U^{0\beta}_{\rho_1 \sigma_2}}\right]$"))
eqs.append((r"$\frac{d\rho}{d t} + \rho \vec{v}\cdot\nabla\vec{v} = -\nabla p + \mu\nabla^2 \vec{v} + \rho \vec{g}$"))
eqs.append((r"$\int_{-\infty}^\infty e^{-x^2}dx=\sqrt{\pi}$"))
eqs.append((r"$E = mc^2 = \sqrt{{m_0}^2c^4 + p^2c^2}$"))
eqs.append((r"$F_G = G\frac{m_1m_2}{r^2}$"))

plt.axes([0.025, 0.025, 0.95, 0.95])

for i in range(24):
    index = np.random.randint(0, len(eqs))
    eq = eqs[index]
    size = np.random.uniform(12, 32)
    x,y = np.random.uniform(0, 1, 2)
    alpha = np.random.uniform(0.25, .75)
    plt.text(x, y, eq, ha='center', va='center', color="#11557c", alpha=alpha,
         transform=plt.gca().transAxes, fontsize=size, clip_on=True)
plt.xticks(())
plt.yticks(())

plt.show()

# %% [markdown]
# ## 1.4.5 这本教程之外
#
# ### 1.4.5.1 教程
#
# ### 1.4.5.2 Matplotlib文档
#
# ### 1.4.5.3 代码文档
#
# ### 1.4.5.4 画廊
#
# ### 1.4.5.5 邮件列表
#
# ## 1.4.6 快速参考
#
# ### 1.4.6.1 Line属性
#
# ### 1.4.6.2 线样式
#
# ### 1.4.6.3 标记
#
# ### 1.4.6.4 Colormaps
